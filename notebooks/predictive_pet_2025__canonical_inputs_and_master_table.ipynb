# %% [markdown]
# we have two input FASTA files of the 4988 sequences that align has given us: [`sequences.fasta`](https://drive.google.com/file/d/1a4QylJ-6hJHqX4stWNn2ff1Qri7ibSxK/view?usp=drive_link) and [`predictive_pet_zero_shot_2025.fasta`](https://drive.google.com/file/d/1mu0XEOoP0A9xfD7Dt56ZFaQGXF9KBcH5/view?usp=drive_link). in order to avoid further confusion amongst members, i am keeping only [`predictive_pet_zero_shot_2025.fasta`](https://drive.google.com/file/d/1mu0XEOoP0A9xfD7Dt56ZFaQGXF9KBcH5/view?usp=drive_link) in our [main SynBio/Software drive](https://drive.google.com/drive/folders/125EA48R64sy8MpH84FqEHlCozqMTOjsr), and archiving [`sequences.fasta`](https://drive.google.com/file/d/1a4QylJ-6hJHqX4stWNn2ff1Qri7ibSxK/view?usp=drive_link) so that no one ends up using this one.
#
# (as you can see from the output below, these files are identical, but i'm keeping only the one named [`predictive_pet_zero_shot_2025.fasta`](https://drive.google.com/file/d/1mu0XEOoP0A9xfD7Dt56ZFaQGXF9KBcH5/view?usp=drive_link) because its name is more specific and consistent with our other notebooks.)

# %%
from google.colab import drive
drive.mount('/content/drive')


# # Mounted at /content/drive
# Out:
# Mounted at /content/drive

# %%
# !wc -l "/content/drive/MyDrive/SynBio Software/data/processed/sequences.fasta" \
      "/content/drive/MyDrive/SynBio Software/data/processed/predictive_pet_zero_shot_2025.fasta"

#   #  9976 /content/drive/MyDrive/SynBio Software/data/processed/sequences.fasta
#   #  9976 /content/drive/MyDrive/SynBio Software/data/processed/predictive_pet_zero_shot_2025.fasta
#   # 19952 total
# Out:
#    9976 /content/drive/MyDrive/SynBio Software/data/processed/sequences.fasta
#    9976 /content/drive/MyDrive/SynBio Software/data/processed/predictive_pet_zero_shot_2025.fasta
#   19952 total

# %%
# !md5sum "/content/drive/MyDrive/SynBio Software/data/processed/sequences.fasta" \
        "/content/drive/MyDrive/SynBio Software/data/processed/predictive_pet_zero_shot_2025.fasta"


# # d689c3ec7b6b5b528ea481d04c05a44a  /content/drive/MyDrive/SynBio Software/data/processed/sequences.fasta
# # d689c3ec7b6b5b528ea481d04c05a44a  /content/drive/MyDrive/SynBio Software/data/processed/predictive_pet_zero_shot_2025.fasta
# Out:
# d689c3ec7b6b5b528ea481d04c05a44a  /content/drive/MyDrive/SynBio Software/data/processed/sequences.fasta
# d689c3ec7b6b5b528ea481d04c05a44a  /content/drive/MyDrive/SynBio Software/data/processed/predictive_pet_zero_shot_2025.fasta
